# %%
# !pip install PyPDF2
import PyPDF2
import re
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
my_file = open('test_resume.pdf', 'rb')

reader = PyPDF2.PdfReader(my_file)

resume_text = reader.pages[0].extract_text()

print("PDF read successfully!")
# Out:
# PDF read successfully!

# %%
def clean_resume_text(text):
    text = re.sub(r'[^\x00-\x7F]+', ' ', text)
    text = text.replace('\n', ' ')
    text = re.sub(r'\s+', ' ', text).strip()
    return text

cleaned_resume = clean_resume_text(resume_text)

print("Here is the CLEANED version:")
print(cleaned_resume)
# Out:
# Here is the CLEANED version:
# ...

# %%
job_description = """
We are looking for an experienced Sales Manager. 
Requirements:
- Strong background in sales, customer negotiation, and conflict resolution.
- Ability to manage team performance and coordinate sales activities.
- Experience with inventory or supply chain management is a plus.
"""

print("Job description created successfully!")
# Out:
# Job description created successfully!

# %%
# !pip install google-generativeai
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install google-genai
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from google import genai

client = genai.Client(api_key="AQ.Ab8RN6JUZGY4sNfSIvJrrl7VWmEURmVJkUQmu8M2AeKU9HM5Pw")

prompt = f"""
You are an expert technical recruiter. Evaluate the candidate's resume strictly against the job description below.

JOB DESCRIPTION:
{job_description}

CANDIDATE RESUME:
{cleaned_resume}

Provide your response in the following format:
1. Score: (Give a number from 1 to 100)
2. Justification: (Write a short, 2-3 sentence explanation for the score)
"""

response = client.models.generate_content(
    model='gemini-3.6-flash',
    contents=prompt,
)

print("AI Evaluation Result:")
print(response.text)
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# AI Evaluation Result:
# 1. Score: 92
#
# 2. Justification: The candidate demonstrates direct, extensive experience as a Sales Manager, perfectly matching core requirements such as team performance management, sales activity coordination, customer negotiation, and conflict resolution. Additionally, their resume explicitly highlights background in inventory control, purchasing, and shipping/receiving operations, directly satisfying the desired preferred qualifications.

# %%
# !pip install streamlit
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %%writefile app.py
import streamlit as st

st.title("AI Resume Screening Tool")
st.write("Welcome to the SafeX internship project interface!")

uploaded_file = st.file_uploader("Upload a resume PDF", type=["pdf"])

if uploaded_file is not None:
    st.success("File uploaded successfully!")
# Out:
# Overwriting app.py

# %%
# !streamlit run app.py
